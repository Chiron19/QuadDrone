# %% [markdown]
# ![image.png](attachment:44759b4c-f0f9-46bd-9bb2-da3452cd3f25.png)
#
# # Flight Control System
#
# ![image.png](attachment:80113c9a-5872-4fd7-afa7-70da13da4ca8.png)

# %% [markdown]
# ## State Estimator
# ![image.png](attachment:1681706f-f75d-48e0-842b-41dd29b3141c.png)

# %% [markdown]
# ![image.png](attachment:31f160fd-7c7d-4163-a215-a1df0742c9ef.png)
