# %% [markdown]
# ![image.png](attachment:cf53d6a2-a1b9-4c9b-8620-d192ce018376.png)
#
# # sensors
#
# ![image.png](attachment:7fb7f52d-d9c3-4d52-a725-9a98ea7307d6.png)
#
# ![image.png](attachment:a485714c-9313-42c7-9812-6310aced8717.png)
#
# # sensordata_data
#
# ![image.png](attachment:5d71fbbc-1fc8-4d0a-888f-e91eefc98b24.png)
