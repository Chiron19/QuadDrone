# %% [markdown]
# # Flight Control System
#
# ![image.png](attachment:44759b4c-f0f9-46bd-9bb2-da3452cd3f25.png)

# %% [markdown]
# - **Input**
#
#     1. AC cmd 控制输入
#     2. Sensors 传感器输入
#     3. Image Data 图象输入
#
# - **Output**
#
#     1. Actuators 执行机构
#
#         motor command: [4\*1 single]
#
#     2. Flag 标记

# %% [markdown]
# # Sensors
#
# - **Bus:sensorData_t:**
#     - [ddx, ddy, ddz]
#     - [p, q, r]
#     - altitute sonar
#     - pressures
#     - Virtual Battery Assessment Tool (VBAT)
#     - VBAT percentage

# %% [markdown]
# ![image.png](attachment:cf53d6a2-a1b9-4c9b-8620-d192ce018376.png)

# %% [markdown]
# ![image.png](attachment:c09bea92-6f79-402e-a02a-697213afcd91.png)
#
# ![image.png](attachment:6038a27f-abe0-4e90-887b-1143f7887c9c.png)
#
# ![image.png](attachment:d33914f6-b8f9-4ea0-9af5-8bc4e9376b8e.png)

# %% [markdown]
# ## IMU_Pressure
#
# 需要接入外设的部分：
#
# - **Output**
#
# 1. $A_{meas}\mathrm{(m/s^2)}$ 加速度
#
# 三个轴：[ddx, ddy, ddz]
#
# 2. $\omega_{meas}\mathrm{(rad/s)}$ 角速度
#
# 三个轴：[p. q. r]
#
# 3. Sonar 超声波
# 4. Pressures 气压计

# %% [markdown]
# ![image.png](attachment:6d926ef9-5fd5-41db-8f88-1ce1e61cb66e.png)
#
# ## Optical Flow
#
# 光流
#
# - **Output**
#
# opticalData：(single, Bus:extraSensorData)
#
# ![image.png](attachment:60f1cdeb-f139-4be8-b33e-526537335b7a.png)
#
# ## Camera
#
# 相机
#
# ![image.png](attachment:38dc7e6a-78dc-4c79-b24f-c88e91ea2533.png)
#
# - **Output**
#
# imageData：图象数据
